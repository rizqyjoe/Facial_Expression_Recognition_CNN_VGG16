# %% [markdown]
# <a href="https://colab.research.google.com/github/rizqyjoe/Facial_Expression_Recognition_CNN_VGG16/blob/main/Model%203/3_85%25_Acc_GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import skimage.io
import keras.backend as K
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization ,Activation
from tensorflow.keras.models import Model, Sequential
from keras.applications.nasnet import NASNetLarge
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
train_datagen = ImageDataGenerator(rescale = 1./255, 
                                   validation_split = 0.2,
                                   rotation_range=5,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_spl it = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255)

# %%
train_dataset  = train_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Dataset/FER2013/images/train',
                                                   target_size = (48,48),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   batch_size = 64)
# Out:
# Found 23068 images belonging to 7 classes.

# %%
valid_dataset = valid_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Dataset/FER2013/images/validation',
                                                  target_size = (48,48),
                                                  class_mode = 'categorical',
                                                  subset = 'validation',
                                                  batch_size = 64)
# Out:
# Found 1411 images belonging to 7 classes.

# %%
base_model = tf.keras.applications.VGG16(input_shape=(48,48,3),
                                         include_top=False,
                                         weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step

# %%
# Freezing Layers

for layer in base_model.layers[:-4]:
    layer.trainable=False

# %%
model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(7,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 1, 1, 512)         14714688
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# dense (Dense)                (None, 32)                16416
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32)                128
# _________________________________________________________________
# activation (Activation)      (None, 32)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# activation_1 (Activation)    (None, 32)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                1056
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32)                128
# _________________________________________________________________
# activation_2 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 14,735,879
# Trainable params: 7,099,399
# Non-trainable params: 7,636,480
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
from IPython.display import Image
plot_model(model, to_file='vgg.png', show_shapes=True,show_layer_names=True)
Image(filename='vgg.png')

# %%
def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# %%
lrd = ReduceLROnPlateau(monitor = 'val_loss',
                        patience = 20,
                        verbose = 1,
                        factor = 0.50, 
                        min_lr = 1e-10)

mcp = ModelCheckpoint('Model3_VGG16FT_Adam0.001.h5')

es = EarlyStopping(verbose=1, 
                   patience=20)

# %%
model.compile(optimizer=Adam(learning_rate=0.001), 
              loss='categorical_crossentropy',
              metrics=METRICS)

# %%
history=model.fit(train_dataset,
                  validation_data=valid_dataset,
                  epochs = 25,
                  verbose = 1,
                  callbacks=[lrd,mcp,es])
# Out:
# Epoch 1/25
# 361/361 [==============================] - 6353s 17s/step - loss: 2.0170 - accuracy: 0.8532 - precision: 0.1607 - recall: 0.0060 - auc: 0.5686 - f1_score: 0.0112 - val_loss: 1.8361 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6353 - val_f1_score: 0.0000e+00
# Epoch 2/25
# 361/361 [==============================] - 67s 185ms/step - loss: 1.8426 - accuracy: 0.8569 - precision: 0.2809 - recall: 0.0012 - auc: 0.6298 - f1_score: 0.0023 - val_loss: 1.8393 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6393 - val_f1_score: 0.0000e+00
# Epoch 3/25
# 361/361 [==============================] - 66s 183ms/step - loss: 1.8167 - accuracy: 0.8569 - precision: 0.4339 - recall: 0.0062 - auc: 0.6445 - f1_score: 0.0120 - val_loss: 1.7727 - val_accuracy: 0.8572 - val_precision: 1.0000 - val_recall: 7.0872e-04 - val_auc: 0.6804 - val_f1_score: 0.0013
# Epoch 4/25
# 361/361 [==============================] - 64s 178ms/step - loss: 1.7803 - accuracy: 0.8566 - precision: 0.3974 - recall: 0.0070 - auc: 0.6723 - f1_score: 0.0136 - val_loss: 1.7522 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6925 - val_f1_score: 0.0000e+00
# Epoch 5/25
# 361/361 [==============================] - 65s 179ms/step - loss: 1.7669 - accuracy: 0.8566 - precision: 0.3027 - recall: 0.0029 - auc: 0.6807 - f1_score: 0.0057 - val_loss: 1.8778 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6318 - val_f1_score: 0.0000e+00
# Epoch 6/25
# 361/361 [==============================] - 65s 180ms/step - loss: 1.7492 - accuracy: 0.8573 - precision: 0.5195 - recall: 0.0099 - auc: 0.6914 - f1_score: 0.0192 - val_loss: 1.8649 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6494 - val_f1_score: 0.0000e+00
# Epoch 7/25
# 361/361 [==============================] - 64s 178ms/step - loss: 1.7437 - accuracy: 0.8575 - precision: 0.5470 - recall: 0.0160 - auc: 0.6940 - f1_score: 0.0309 - val_loss: 1.7449 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6961 - val_f1_score: 0.0000e+00
# Epoch 8/25
# 361/361 [==============================] - 65s 181ms/step - loss: 1.7584 - accuracy: 0.8575 - precision: 0.5759 - recall: 0.0081 - auc: 0.6835 - f1_score: 0.0158 - val_loss: 1.8865 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6368 - val_f1_score: 0.0000e+00
# Epoch 9/25
# 361/361 [==============================] - 65s 180ms/step - loss: 1.7484 - accuracy: 0.8578 - precision: 0.5880 - recall: 0.0155 - auc: 0.6889 - f1_score: 0.0300 - val_loss: 1.8116 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6604 - val_f1_score: 0.0000e+00
# Epoch 10/25
# 361/361 [==============================] - 65s 180ms/step - loss: 1.7342 - accuracy: 0.8579 - precision: 0.5719 - recall: 0.0205 - auc: 0.6973 - f1_score: 0.0393 - val_loss: 1.7270 - val_accuracy: 0.8575 - val_precision: 0.8333 - val_recall: 0.0035 - val_auc: 0.7003 - val_f1_score: 0.0066
# Epoch 11/25
# 361/361 [==============================] - 65s 179ms/step - loss: 1.7335 - accuracy: 0.8578 - precision: 0.5559 - recall: 0.0194 - auc: 0.6977 - f1_score: 0.0373 - val_loss: 1.7410 - val_accuracy: 0.8573 - val_precision: 1.0000 - val_recall: 0.0014 - val_auc: 0.6945 - val_f1_score: 0.0027
# Epoch 12/25
# 361/361 [==============================] - 64s 179ms/step - loss: 1.7193 - accuracy: 0.8582 - precision: 0.5954 - recall: 0.0239 - auc: 0.7049 - f1_score: 0.0458 - val_loss: 1.7636 - val_accuracy: 0.8572 - val_precision: 1.0000 - val_recall: 7.0872e-04 - val_auc: 0.6805 - val_f1_score: 0.0013
# Epoch 13/25
# 361/361 [==============================] - 65s 180ms/step - loss: 1.7198 - accuracy: 0.8586 - precision: 0.6142 - recall: 0.0276 - auc: 0.7047 - f1_score: 0.0527 - val_loss: 1.7555 - val_accuracy: 0.8583 - val_precision: 0.5369 - val_recall: 0.0567 - val_auc: 0.6836 - val_f1_score: 0.0969
# Epoch 14/25
# 361/361 [==============================] - 65s 179ms/step - loss: 1.7155 - accuracy: 0.8580 - precision: 0.5896 - recall: 0.0209 - auc: 0.7070 - f1_score: 0.0400 - val_loss: 1.7460 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6947 - val_f1_score: 0.0000e+00
# Epoch 15/25
# 361/361 [==============================] - 64s 177ms/step - loss: 1.7220 - accuracy: 0.8587 - precision: 0.6240 - recall: 0.0280 - auc: 0.7015 - f1_score: 0.0533 - val_loss: 1.7336 - val_accuracy: 0.8573 - val_precision: 1.0000 - val_recall: 0.0014 - val_auc: 0.7007 - val_f1_score: 0.0027
# Epoch 16/25
# 361/361 [==============================] - 64s 179ms/step - loss: 1.7079 - accuracy: 0.8585 - precision: 0.6073 - recall: 0.0269 - auc: 0.7097 - f1_score: 0.0513 - val_loss: 1.8062 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6678 - val_f1_score: 0.0000e+00
# Epoch 17/25
# 361/361 [==============================] - 64s 178ms/step - loss: 1.7025 - accuracy: 0.8585 - precision: 0.5960 - recall: 0.0300 - auc: 0.7126 - f1_score: 0.0569 - val_loss: 1.7299 - val_accuracy: 0.8575 - val_precision: 0.7500 - val_recall: 0.0043 - val_auc: 0.7008 - val_f1_score: 0.0079
# Epoch 18/25
# 361/361 [==============================] - 64s 178ms/step - loss: 1.6996 - accuracy: 0.8586 - precision: 0.6004 - recall: 0.0302 - auc: 0.7146 - f1_score: 0.0573 - val_loss: 1.6818 - val_accuracy: 0.8597 - val_precision: 0.6667 - val_recall: 0.0354 - val_auc: 0.7170 - val_f1_score: 0.0637
# Epoch 19/25
# 361/361 [==============================] - 64s 178ms/step - loss: 1.6916 - accuracy: 0.8592 - precision: 0.6501 - recall: 0.0319 - auc: 0.7161 - f1_score: 0.0607 - val_loss: 1.6962 - val_accuracy: 0.8578 - val_precision: 0.7143 - val_recall: 0.0071 - val_auc: 0.7171 - val_f1_score: 0.0133
# Epoch 20/25
# 361/361 [==============================] - 64s 178ms/step - loss: 1.7007 - accuracy: 0.8583 - precision: 0.5844 - recall: 0.0265 - auc: 0.7133 - f1_score: 0.0506 - val_loss: 1.7308 - val_accuracy: 0.8574 - val_precision: 0.8000 - val_recall: 0.0028 - val_auc: 0.7046 - val_f1_score: 0.0054
# Epoch 21/25
# 361/361 [==============================] - 65s 180ms/step - loss: 1.6907 - accuracy: 0.8588 - precision: 0.6185 - recall: 0.0306 - auc: 0.7175 - f1_score: 0.0580 - val_loss: 1.7301 - val_accuracy: 0.8571 - val_precision: 0.5000 - val_recall: 0.0035 - val_auc: 0.7027 - val_f1_score: 0.0066
# Epoch 22/25
# 361/361 [==============================] - 65s 180ms/step - loss: 1.6907 - accuracy: 0.8590 - precision: 0.6270 - recall: 0.0316 - auc: 0.7177 - f1_score: 0.0600 - val_loss: 1.6983 - val_accuracy: 0.8575 - val_precision: 0.6250 - val_recall: 0.0071 - val_auc: 0.7180 - val_f1_score: 0.0132
# Epoch 23/25
# 361/361 [==============================] - 65s 180ms/step - loss: 1.6846 - accuracy: 0.8587 - precision: 0.6076 - recall: 0.0307 - auc: 0.7206 - f1_score: 0.0582 - val_loss: 1.7290 - val_accuracy: 0.8573 - val_precision: 1.0000 - val_recall: 0.0014 - val_auc: 0.7070 - val_f1_score: 0.0027
# Epoch 24/25
# 361/361 [==============================] - 65s 179ms/step - loss: 1.6934 - accuracy: 0.8590 - precision: 0.6502 - recall: 0.0278 - auc: 0.7147 - f1_score: 0.0531 - val_loss: 1.6799 - val_accuracy: 0.8576 - val_precision: 0.6471 - val_recall: 0.0078 - val_auc: 0.7217 - val_f1_score: 0.0145
# Epoch 25/25
# 361/361 [==============================] - 64s 178ms/step - loss: 1.6882 - accuracy: 0.8593 - precision: 0.6526 - recall: 0.0329 - auc: 0.7203 - f1_score: 0.0624 - val_loss: 1.7043 - val_accuracy: 0.8578 - val_precision: 0.6667 - val_recall: 0.0085 - val_auc: 0.7144 - val_f1_score: 0.0159

# %%
#%% PLOTTING RESULTS (Train vs Validation FOLDER 1)

def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1,val_f1):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    

Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision'],
               history.history['f1_score'],history.history['val_f1_score']
              )
