# %% [markdown]
# <a href="https://colab.research.google.com/github/rizqyjoe/Facial_Expression_Recognition_CNN_VGG16/blob/main/Model%203/2_86%25_Acc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import skimage.io
import keras.backend as K
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization ,Activation
from tensorflow.keras.models import Model, Sequential
from keras.applications.nasnet import NASNetLarge
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
train_datagen = ImageDataGenerator(rescale = 1./255, 
                                   validation_split = 0.2,
                                   rotation_range=5,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255)

# %%
train_dataset  = train_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Dataset/FER2013/images/train',
                                                   target_size = (48,48),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   batch_size = 64)
# Out:
# Found 23068 images belonging to 7 classes.

# %%
valid_dataset = valid_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Dataset/FER2013/images/validation',
                                                  target_size = (48,48),
                                                  class_mode = 'categorical',
                                                  subset = 'validation',
                                                  batch_size = 64)
# Out:
# Found 1411 images belonging to 7 classes.

# %%
base_model = tf.keras.applications.VGG16(input_shape=(48,48,3),
                                         include_top=False,
                                         weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step

# %%
# Freezing Layers

for layer in base_model.layers[:-4]:
    layer.trainable=False

# %%
model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(7,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 1, 1, 512)         14714688
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# dense (Dense)                (None, 32)                16416
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32)                128
# _________________________________________________________________
# activation (Activation)      (None, 32)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# activation_1 (Activation)    (None, 32)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                1056
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32)                128
# _________________________________________________________________
# activation_2 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 14,735,879
# Trainable params: 7,099,399
# Non-trainable params: 7,636,480
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
from IPython.display import Image
plot_model(model, to_file='vgg.png', show_shapes=True,show_layer_names=True)
Image(filename='vgg.png')

# %%
def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# %%
lrd = ReduceLROnPlateau(monitor = 'val_loss',
                        patience = 20,
                        verbose = 1,
                        factor = 0.50, 
                        min_lr = 1e-10)

mcp = ModelCheckpoint('Model3_VGG16FT_Adam0.001.h5')

es = EarlyStopping(verbose=1, 
                   patience=20)

# %%
model.compile(optimizer=Adam(learning_rate=0.001), 
              loss='categorical_crossentropy',
              metrics=METRICS)

# %%
history=model.fit(train_dataset,
                  validation_data=valid_dataset,
                  epochs = 25,
                  verbose = 1,
                  callbacks=[lrd,mcp,es])
# Out:
# Epoch 1/25
# 361/361 [==============================] - 936s 3s/step - loss: 1.7236 - accuracy: 0.8581 - precision: 0.5827 - recall: 0.0243 - auc: 0.7029 - f1_score: 0.0465 - val_loss: 1.6818 - val_accuracy: 0.8596 - val_precision: 0.7222 - val_recall: 0.0276 - val_auc: 0.7208 - val_f1_score: 0.0502
# Epoch 2/25
# 361/361 [==============================] - 942s 3s/step - loss: 1.7130 - accuracy: 0.8586 - precision: 0.6072 - recall: 0.0285 - auc: 0.7070 - f1_score: 0.0541 - val_loss: 1.7404 - val_accuracy: 0.8580 - val_precision: 0.8333 - val_recall: 0.0071 - val_auc: 0.6970 - val_f1_score: 0.0132
# Epoch 3/25
# 361/361 [==============================] - 938s 3s/step - loss: 1.7173 - accuracy: 0.8588 - precision: 0.6294 - recall: 0.0278 - auc: 0.7042 - f1_score: 0.0529 - val_loss: 1.8395 - val_accuracy: 0.8563 - val_precision: 0.4808 - val_recall: 0.0709 - val_auc: 0.6433 - val_f1_score: 0.1172
# Epoch 4/25
# 361/361 [==============================] - 952s 3s/step - loss: 1.7400 - accuracy: 0.8579 - precision: 0.6019 - recall: 0.0165 - auc: 0.6943 - f1_score: 0.0317 - val_loss: 1.8823 - val_accuracy: 0.8570 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6515 - val_f1_score: 0.0000e+00
# Epoch 5/25
# 361/361 [==============================] - 936s 3s/step - loss: 1.7155 - accuracy: 0.8585 - precision: 0.6099 - recall: 0.0261 - auc: 0.7071 - f1_score: 0.0498 - val_loss: 1.7959 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6725 - val_f1_score: 0.0000e+00
# Epoch 6/25
# 361/361 [==============================] - 937s 3s/step - loss: 1.7095 - accuracy: 0.8586 - precision: 0.6177 - recall: 0.0272 - auc: 0.7089 - f1_score: 0.0518 - val_loss: 1.7464 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6950 - val_f1_score: 0.0000e+00
# Epoch 7/25
# 361/361 [==============================] - 942s 3s/step - loss: 1.7051 - accuracy: 0.8589 - precision: 0.6299 - recall: 0.0300 - auc: 0.7104 - f1_score: 0.0569 - val_loss: 1.7233 - val_accuracy: 0.8574 - val_precision: 0.7143 - val_recall: 0.0035 - val_auc: 0.7033 - val_f1_score: 0.0066
# Epoch 8/25
# 361/361 [==============================] - 934s 3s/step - loss: 1.7014 - accuracy: 0.8586 - precision: 0.6011 - recall: 0.0294 - auc: 0.7130 - f1_score: 0.0559 - val_loss: 1.6915 - val_accuracy: 0.8575 - val_precision: 0.6250 - val_recall: 0.0071 - val_auc: 0.7187 - val_f1_score: 0.0133
# Epoch 9/25
# 361/361 [==============================] - 936s 3s/step - loss: 1.6981 - accuracy: 0.8591 - precision: 0.6481 - recall: 0.0303 - auc: 0.7132 - f1_score: 0.0576 - val_loss: 1.9718 - val_accuracy: 0.8581 - val_precision: 0.5246 - val_recall: 0.0680 - val_auc: 0.7046 - val_f1_score: 0.1143
# Epoch 10/25
# 361/361 [==============================] - 938s 3s/step - loss: 1.6924 - accuracy: 0.8592 - precision: 0.6345 - recall: 0.0333 - auc: 0.7170 - f1_score: 0.0631 - val_loss: 2.1177 - val_accuracy: 0.8593 - val_precision: 0.7692 - val_recall: 0.0213 - val_auc: 0.7285 - val_f1_score: 0.0393
# Epoch 11/25
# 361/361 [==============================] - 952s 3s/step - loss: 1.6968 - accuracy: 0.8587 - precision: 0.6170 - recall: 0.0289 - auc: 0.7147 - f1_score: 0.0550 - val_loss: 4.5236 - val_accuracy: 0.7466 - val_precision: 0.1128 - val_recall: 0.1127 - val_auc: 0.5231 - val_f1_score: 0.1081
# Epoch 12/25
# 361/361 [==============================] - 944s 3s/step - loss: 1.7148 - accuracy: 0.8584 - precision: 0.6232 - recall: 0.0219 - auc: 0.7061 - f1_score: 0.0420 - val_loss: 1.8482 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6595 - val_f1_score: 0.0000e+00
# Epoch 13/25
# 361/361 [==============================] - 946s 3s/step - loss: 1.7048 - accuracy: 0.8582 - precision: 0.5951 - recall: 0.0241 - auc: 0.7123 - f1_score: 0.0461 - val_loss: 1.7516 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6935 - val_f1_score: 0.0000e+00
# Epoch 14/25
# 361/361 [==============================] - 929s 3s/step - loss: 1.6993 - accuracy: 0.8587 - precision: 0.6207 - recall: 0.0289 - auc: 0.7144 - f1_score: 0.0551 - val_loss: 1.6728 - val_accuracy: 0.8584 - val_precision: 0.7308 - val_recall: 0.0135 - val_auc: 0.7271 - val_f1_score: 0.0252
# Epoch 15/25
# 361/361 [==============================] - 928s 3s/step - loss: 1.6979 - accuracy: 0.8588 - precision: 0.6282 - recall: 0.0286 - auc: 0.7155 - f1_score: 0.0546 - val_loss: 1.7397 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6953 - val_f1_score: 0.0000e+00
# Epoch 16/25
# 361/361 [==============================] - 929s 3s/step - loss: 1.6954 - accuracy: 0.8589 - precision: 0.6318 - recall: 0.0301 - auc: 0.7149 - f1_score: 0.0573 - val_loss: 1.6734 - val_accuracy: 0.8572 - val_precision: 0.5455 - val_recall: 0.0043 - val_auc: 0.7295 - val_f1_score: 0.0080
# Epoch 17/25
# 361/361 [==============================] - 934s 3s/step - loss: 1.6865 - accuracy: 0.8594 - precision: 0.6550 - recall: 0.0333 - auc: 0.7187 - f1_score: 0.0633 - val_loss: 1.6661 - val_accuracy: 0.8583 - val_precision: 0.7200 - val_recall: 0.0128 - val_auc: 0.7332 - val_f1_score: 0.0238
# Epoch 18/25
# 361/361 [==============================] - 947s 3s/step - loss: 1.6865 - accuracy: 0.8588 - precision: 0.6294 - recall: 0.0288 - auc: 0.7189 - f1_score: 0.0548 - val_loss: 1.6954 - val_accuracy: 0.8573 - val_precision: 0.6667 - val_recall: 0.0028 - val_auc: 0.7177 - val_f1_score: 0.0054
# Epoch 19/25
# 361/361 [==============================] - 963s 3s/step - loss: 1.6766 - accuracy: 0.8593 - precision: 0.6474 - recall: 0.0334 - auc: 0.7243 - f1_score: 0.0633 - val_loss: 1.6929 - val_accuracy: 0.8572 - val_precision: 0.5556 - val_recall: 0.0035 - val_auc: 0.7186 - val_f1_score: 0.0067
# Epoch 20/25
# 361/361 [==============================] - 959s 3s/step - loss: 1.6788 - accuracy: 0.8591 - precision: 0.6187 - recall: 0.0358 - auc: 0.7224 - f1_score: 0.0673 - val_loss: 1.8583 - val_accuracy: 0.8532 - val_precision: 0.4184 - val_recall: 0.0709 - val_auc: 0.6674 - val_f1_score: 0.1159
# Epoch 21/25
# 361/361 [==============================] - 961s 3s/step - loss: 1.6598 - accuracy: 0.8603 - precision: 0.6173 - recall: 0.0580 - auc: 0.7299 - f1_score: 0.1051 - val_loss: 1.7033 - val_accuracy: 0.8594 - val_precision: 0.7750 - val_recall: 0.0220 - val_auc: 0.7393 - val_f1_score: 0.0401
# Epoch 22/25
# 361/361 [==============================] - 951s 3s/step - loss: 1.6432 - accuracy: 0.8620 - precision: 0.6199 - recall: 0.0887 - auc: 0.7389 - f1_score: 0.1536 - val_loss: 1.6211 - val_accuracy: 0.8715 - val_precision: 0.7773 - val_recall: 0.1410 - val_auc: 0.7577 - val_f1_score: 0.2481
# Epoch 23/25
# 361/361 [==============================] - 959s 3s/step - loss: 1.6290 - accuracy: 0.8633 - precision: 0.6283 - recall: 0.1050 - auc: 0.7451 - f1_score: 0.1790 - val_loss: 1.5812 - val_accuracy: 0.8701 - val_precision: 0.7119 - val_recall: 0.1524 - val_auc: 0.7621 - val_f1_score: 0.2395
# Epoch 24/25
# 361/361 [==============================] - 956s 3s/step - loss: 1.6203 - accuracy: 0.8642 - precision: 0.6355 - recall: 0.1158 - auc: 0.7495 - f1_score: 0.1952 - val_loss: 1.5540 - val_accuracy: 0.8694 - val_precision: 0.6649 - val_recall: 0.1729 - val_auc: 0.7710 - val_f1_score: 0.2608
# Epoch 25/25
# 361/361 [==============================] - 948s 3s/step - loss: 1.6059 - accuracy: 0.8652 - precision: 0.6434 - recall: 0.1270 - auc: 0.7562 - f1_score: 0.2107 - val_loss: 1.5563 - val_accuracy: 0.8702 - val_precision: 0.7143 - val_recall: 0.1524 - val_auc: 0.7745 - val_f1_score: 0.2369

# %%
#%% PLOTTING RESULTS (Train vs Validation FOLDER 1)

def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1,val_f1):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    

Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision'],
               history.history['f1_score'],history.history['val_f1_score']
              )
